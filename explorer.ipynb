# %%
import pandas as pd

# %%
df = pd.read_pickle('downloads/0x3416cf6c708da44db2624d63ea0aaef7113527c6_2025-11-07t00-00-00z_/outputs/merged/0x3416cf6c708da44db2624d63ea0aaef7113527c6.pkl')
df
# Out:
#    eventType   timestamp  blockNumber  \
# 0   swap_x2y  1762473623     23743680
# 1   swap_y2x  1762473647     23743682
# 2   swap_y2x  1762473647     23743682
# 3   swap_x2y  1762473647     23743682
# 4   swap_x2y  1762473671     23743684
# 5   swap_y2x  1762473683     23743685
# 6   swap_x2y  1762473695     23743686
# 7   swap_x2y  1762473695     23743686
# 8   swap_x2y  1762473707     23743687
# 9   swap_x2y  1762473791     23743694
# 10  swap_y2x  1762473803     23743695
# 11  swap_x2y  1762473851     23743699
# 12  swap_x2y  1762473887     23743702
# 13  swap_x2y  1762473923     23743705
# 14  swap_x2y  1762473971     23743709
# 15  swap_y2x  1762473983     23743710
# 16  swap_y2x  1762474127     23743722
# 17  swap_y2x  1762474235     23743731
# 18  swap_y2x  1762474235     23743731
# 19  swap_x2y  1762474259     23743733
# 20  swap_y2x  1762474355     23743741
# 21  swap_x2y  1762474403     23743745
# 22  swap_x2y  1762474607     23743761
# ...
